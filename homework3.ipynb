# %% [markdown]
# <a href="https://colab.research.google.com/github/farruxisomiddinov326-cell/collab_uchun/blob/main/homework3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import numpy as np

# %%
from pandas import Series

# %%
obj = Series([4,7,6,-6.5])

# %%
print(obj)
# Out:
# 0    4.0
# 1    7.0
# 2    6.0
# 3   -6.5
# dtype: float64

# %%
obj.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
obj.values
# Out:
# array([ 4. ,  7. ,  6. , -6.5])

# %%
obj[0]
# Out:
# np.float64(4.0)

# %%
np.float64(4.0)
# Out:
# np.float64(4.0)

# %%
obj2 = Series([1,2,3],index=['a','b','c'])
obj2
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
dtype:np.int64

# %%
s = Series([85,90,78], index=["ali", "vali", "sami"])
s
# Out:
# ali     85
# vali    90
# sami    78
# dtype: int64

# %%
obj2[obj2 < 3]
# Out:
# a    1
# b    2
# dtype: int64

# %%
obj * 2
# Out:
# 0     8.0
# 1    14.0
# 2    12.0
# 3   -13.0
# dtype: float64

# %%
from google.colab import files
upload = files.upload()
# Out:
#      <input type="file" id="files-43154fbb-fe5c-4ee9-977e-7092e1c24539" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-43154fbb-fe5c-4ee9-977e-7092e1c24539">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('Talabalar_.csv')
df.head()
# Out:
#    ID    Name  Gender Age Score Enrollment Date          Phone
# 0   1     NaN    male  20    64      09.02.2026   998902458591
# 1   2  Lola      MALE  17    85        26.02.13            NaN
# 2   3  Sami    female  22    67      2026/02/10   998906647119
# 3   4  Anna      male  29    52        26.03.19  99890 3094235
# 4   5   Zara     MALE  20    95      05.02.2026   998904823498

# %%
df.isnull().sum()
# Out:
# ID                   0
# Name                25
# Gender               0
# Age                 28
# Score                6
# Enrollment Date      0
# Phone              180
# dtype: int64

# %%
df.shape
# Out:
# (500, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               500 non-null    int64
#  1   Name             475 non-null    object
#  2   Gender           500 non-null    object
#  3   Age              472 non-null    object
#  4   Score            494 non-null    object
#  5   Enrollment Date  500 non-null    object
#  6   Phone            320 non-null    object
# dtypes: int64(1), object(6)
# memory usage: 27.5+ KB

# %%
df.isnull().any()
# Out:
# ID                 False
# Name                True
# Gender             False
# Age                 True
# Score               True
# Enrollment Date    False
# Phone               True
# dtype: bool

# %%
df.columns = df.columns.str.strip().str.lower().str.replace(" ", "_")

# %%
df.head()
# Out:
#    id    name  gender age score enrollment_date          phone
# 0   1     NaN    male  20    64      09.02.2026   998902458591
# 1   2  Lola      MALE  17    85        26.02.13            NaN
# 2   3  Sami    female  22    67      2026/02/10   998906647119
# 3   4  Anna      male  29    52        26.03.19  99890 3094235
# 4   5   Zara     MALE  20    95      05.02.2026   998904823498

# %%
df["name"] = df["name"].str.strip()
df["gender"] = df["gender"].str.strip().str.lower()

# %%
df.head()
# Out:
#    id  name  gender age score enrollment_date          phone
# 0   1   NaN    male  20    64      09.02.2026   998902458591
# 1   2  Lola    male  17    85        26.02.13            NaN
# 2   3  Sami  female  22    67      2026/02/10   998906647119
# 3   4  Anna    male  29    52        26.03.19  99890 3094235
# 4   5  Zara    male  20    95      05.02.2026   998904823498

# %%
df["gender"] = df["gender"].replace({
    "phone": "phone",
    "score": "score"
})

# %%
df.head()
# Out:
#    id  name  gender age score enrollment_date          phone
# 0   1   NaN    male  20    64      09.02.2026   998902458591
# 1   2  Lola    male  17    85        26.02.13            NaN
# 2   3  Sami  female  22    67      2026/02/10   998906647119
# 3   4  Anna    male  29    52        26.03.19  99890 3094235
# 4   5  Zara    male  20    95      05.02.2026   998904823498

# %%
df["gender"].value_counts()
# Out:
# gender
# female    252
# male      248
# Name: count, dtype: int64

# %%
df["age"] = pd.to_numeric(df["age"], errors="coerce")

# %%
df.head()
# Out:
#    id  name  gender   age score enrollment_date          phone
# 0   1   NaN    male  20.0    64      09.02.2026   998902458591
# 1   2  Lola    male  17.0    85        26.02.13            NaN
# 2   3  Sami  female  22.0    67      2026/02/10   998906647119
# 3   4  Anna    male  29.0    52        26.03.19  99890 3094235
# 4   5  Zara    male  20.0    95      05.02.2026   998904823498

# %%
df["enrollment_date"] = pd.to_datetime(df["enrollment_date"], errors="coerce")

# %%
df.head()
# Out:
#    id  name  gender   age score enrollment_date          phone
# 0   1   NaN    male  20.0    64      2026-09-02   998902458591
# 1   2  Lola    male  17.0    85             NaT            NaN
# 2   3  Sami  female  22.0    67             NaT   998906647119
# 3   4  Anna    male  29.0    52             NaT  99890 3094235
# 4   5  Zara    male  20.0    95      2026-05-02   998904823498

# %%
df["phone"] = df["phone"].astype(str).str.replace(" ", "")

# %%
df.head()
# Out:
#    id  name  gender   age score enrollment_date         phone
# 0   1   NaN    male  20.0    64      2026-09-02  998902458591
# 1   2  Lola    male  17.0    85             NaT           nan
# 2   3  Sami  female  22.0    67             NaT  998906647119
# 3   4  Anna    male  29.0    52             NaT  998903094235
# 4   5  Zara    male  20.0    95      2026-05-02  998904823498
